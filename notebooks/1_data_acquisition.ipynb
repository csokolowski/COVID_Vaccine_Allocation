# %% [markdown]
# # Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# # Helper Functions

# %%
def get_all_states(url):
    
    """
    Since SODA endpoints limit requests to 1000 rows per request, this function cycles through all states to get
    all rows (assuming data exists in one of the states)
    """
    
    #List of all states uppered
    states = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", "Wisconsin", "West Virginia", "Wyoming"]
    states = [state.upper() for state in states]
    
    df = pd.DataFrame()
    for state in states:
        res = requests.get(url + state)
        df = pd.concat([df, pd.DataFrame(res.json())], axis=0)
        
    return df

# %% [markdown]
# # Initial Contact

# %%
url = 'https://data.cdc.gov/resource/q9mh-h2tw.json'

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
df = pd.DataFrame(res.json())

# %%
df.head(1)
# Out:
#   fips_code                 county_name    state estimated_hesitant  \
# 0      1123  Tallapoosa County, Alabama  ALABAMA             0.1806
#
#   estimated_hesitant_or_unsure estimated_strongly_hesitant  \
# 0                         0.24                      0.1383
#
#   social_vulnerability_index             svi_category  \
# 0                       0.89  Very High Vulnerability
#
#   ability_to_handle_a_covid cvac_category  ... percent_non_hispanic_asian  \
# 0                      0.64  High Concern  ...                     0.0036
#
#   percent_non_hispanic_black percent_non_hispanic_native  \
# 0                     0.2697                           0
#
#   percent_non_hispanic_white  \
# 0                     0.6887
#
#                                   geographical_point state_code  \
# 0  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
#
#                                      county_boundary  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
#
# ...

# %%
df.shape
# Out:
# (1000, 23)

# %% [markdown]
# # Data Acquisition

# %%
states = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", "Wisconsin", "West Virginia", "Wyoming"]
states = [state.upper() for state in states]

# %%
df = get_all_states('https://data.cdc.gov/resource/q9mh-h2tw.json?state=')

# %%
df
# Out:
#    fips_code                         county_name    state estimated_hesitant  \
# 0       2013      Aleutians East Borough, Alaska   ALASKA             0.2361
# 1       2016  Aleutians West Census Area, Alaska   ALASKA             0.2361
# 2       2050          Bethel Census Area, Alaska   ALASKA             0.2361
# 3       2275   Wrangell City and Borough, Alaska   ALASKA             0.2361
# 4       2122     Kenai Peninsula Borough, Alaska   ALASKA              0.186
# ..       ...                                 ...      ...                ...
# 18     56035            Sublette County, Wyoming  WYOMING             0.2184
# 19     56009            Converse County, Wyoming  WYOMING             0.2251
# 20     56029                Park County, Wyoming  WYOMING              0.205
# 21     56019             Johnson County, Wyoming  WYOMING             0.2283
# 22     56001              Albany County, Wyoming  WYOMING             0.1949
#
# ...
